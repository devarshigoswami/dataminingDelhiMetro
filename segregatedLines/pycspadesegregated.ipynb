# %%
import csv
import pandas as pd
from pycspade.helpers import spade, print_result

# %%
resultln1 = spade(filename='dln1.txt', support=0.5, parse=True)
rln1=pd.DataFrame(resultln1)

# %%
resultln2 = spade(filename='dln2.txt', support=0.5, parse=True)
rln2=pd.DataFrame(resultln2)

# %%
resultln3 = spade(filename='dln3.txt', support=0.5, parse=True)
rln3=pd.DataFrame(resultln3)

# %%
resultln4 = spade(filename='dln4.txt', support=0.5, parse=True)
rln4=pd.DataFrame(resultln4)

# %%
resultln5 = spade(filename='dln5.txt', support=0.5, parse=True)
rln5=pd.DataFrame(resultln5)

# %%
rln1
# Out:
#    nsequences                                            seqstrm  \
# 0          93  101 -- 53 53 \n113 -- 49 49 \n114 -- 47 47 \n1...
# 1          93  101 -- 53 53 \n113 -- 49 49 \n114 -- 47 47 \n1...
# 2          93  101 -- 53 53 \n113 -- 49 49 \n114 -- 47 47 \n1...
# 3          93  101 -- 53 53 \n113 -- 49 49 \n114 -- 47 47 \n1...
# 4          93  101 -- 53 53 \n113 -- 49 49 \n114 -- 47 47 \n1...
# 5          93  101 -- 53 53 \n113 -- 49 49 \n114 -- 47 47 \n1...
#
#                                               logger  \
# 0  CONF 93 1190 37.1679 5.69892\nargs.MINSUPPORT ...
# 1  CONF 93 1190 37.1679 5.69892\nargs.MINSUPPORT ...
# 2  CONF 93 1190 37.1679 5.69892\nargs.MINSUPPORT ...
# 3  CONF 93 1190 37.1679 5.69892\nargs.MINSUPPORT ...
# 4  CONF 93 1190 37.1679 5.69892\nargs.MINSUPPORT ...
# 5  CONF 93 1190 37.1679 5.69892\nargs.MINSUPPORT ...
#
#                                              summary mined_objects
# 0  CONF 93 1190 5.69892 37.1679 530 1 245 18.4493...  (101) - [53]
# 1  CONF 93 1190 5.69892 37.1679 530 1 245 18.4493...  (113) - [49]
# 2  CONF 93 1190 5.69892 37.1679 530 1 245 18.4493...  (114) - [47]
# 3  CONF 93 1190 5.69892 37.1679 530 1 245 18.4493...  (134) - [47]
# 4  CONF 93 1190 5.69892 37.1679 530 1 245 18.4493...  (255) - [76]
# 5  CONF 93 1190 5.69892 37.1679 530 1 245 18.4493...  (293) - [49]

# %%
rln2
# Out:
#     nsequences                                            seqstrm  \
# 0           79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 1           79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 2           79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 3           79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 4           79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 5           79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 6           79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 7           79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 8           79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 9           79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 10          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 11          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 12          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 13          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 14          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 15          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 16          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 17          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 18          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 19          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 20          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 21          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 22          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 23          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 24          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 25          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 26          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 27          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 28          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 29          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 30          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
# 31          79  420 -- 56 56 \n508 -- 43 43 \n571 -- 56 56 \n5...
#
#                                                logger  \
# 0   CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 1   CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 2   CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 3   CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 4   CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 5   CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 6   CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 7   CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 8   CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 9   CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 10  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 11  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 12  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 13  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 14  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 15  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 16  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 17  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 18  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 19  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 20  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 21  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 22  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 23  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 24  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 25  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 26  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 27  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 28  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 29  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 30  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
# 31  CONF 79 1168 29.375 4.4557\nargs.MINSUPPORT 40...
#
#                                               summary mined_objects
# 0   CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (420) - [56]
# 1   CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (508) - [43]
# 2   CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (571) - [56]
# 3   CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (573) - [50]
# 4   CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (574) - [50]
# 5   CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (575) - [54]
# 6   CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (592) - [50]
# 7   CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (601) - [53]
# 8   CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (608) - [52]
# 9   CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (611) - [47]
# 10  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (612) - [52]
# 11  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (618) - [41]
# 12  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (621) - [54]
# 13  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (622) - [54]
# 14  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (624) - [43]
# 15  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (625) - [54]
# 16  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (631) - [46]
# 17  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (632) - [54]
# 18  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (640) - [40]
# 19  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (642) - [48]
# 20  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (648) - [53]
# 21  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (649) - [47]
# 22  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (652) - [43]
# 23  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (662) - [54]
# 24  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (664) - [56]
# 25  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (669) - [51]
# 26  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (670) - [48]
# 27  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (671) - [48]
# 28  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (674) - [50]
# 29  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (677) - [61]
# 30  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (682) - [46]
# 31  CONF 79 1168 4.4557 29.375 352 1 229 13.8612 5...  (916) - [41]

# %%
rln3
# Out:
#      nsequences                                            seqstrm  \
# 0            39  101 -- 39 39 \n102 -- 36 36 \n103 -- 37 37 \n1...
# 1            39  101 -- 39 39 \n102 -- 36 36 \n103 -- 37 37 \n1...
# 2            39  101 -- 39 39 \n102 -- 36 36 \n103 -- 37 37 \n1...
# 3            39  101 -- 39 39 \n102 -- 36 36 \n103 -- 37 37 \n1...
# 4            39  101 -- 39 39 \n102 -- 36 36 \n103 -- 37 37 \n1...
# ..          ...                                                ...
# 416          39  101 -- 39 39 \n102 -- 36 36 \n103 -- 37 37 \n1...
# 417          39  101 -- 39 39 \n102 -- 36 36 \n103 -- 37 37 \n1...
# 418          39  101 -- 39 39 \n102 -- 36 36 \n103 -- 37 37 \n1...
# 419          39  101 -- 39 39 \n102 -- 36 36 \n103 -- 37 37 \n1...
# 420          39  101 -- 39 39 \n102 -- 36 36 \n103 -- 37 37 \n1...
#
#                                                 logger  \
# 0    CONF 39 1104 23.3554 6.20513\nargs.MINSUPPORT ...
# 1    CONF 39 1104 23.3554 6.20513\nargs.MINSUPPORT ...
# 2    CONF 39 1104 23.3554 6.20513\nargs.MINSUPPORT ...
# 3    CONF 39 1104 23.3554 6.20513\nargs.MINSUPPORT ...
# 4    CONF 39 1104 23.3554 6.20513\nargs.MINSUPPORT ...
# ..                                                 ...
# 416  CONF 39 1104 23.3554 6.20513\nargs.MINSUPPORT ...
# 417  CONF 39 1104 23.3554 6.20513\nargs.MINSUPPORT ...
# 418  CONF 39 1104 23.3554 6.20513\nargs.MINSUPPORT ...
# 419  CONF 39 1104 23.3554 6.20513\nargs.MINSUPPORT ...
# 420  CONF 39 1104 23.3554 6.20513\nargs.MINSUPPORT ...
#
#                                                summary        mined_objects
# 0    CONF 39 1104 6.20513 23.3554 242 1 55 5.4996 4...         (101) - [39]
# 1    CONF 39 1104 6.20513 23.3554 242 1 55 5.4996 4...  (101)->(101) - [21]
# 2    CONF 39 1104 6.20513 23.3554 242 1 55 5.4996 4...  (101)->(102) - [23]
# 3    CONF 39 1104 6.20513 23.3554 242 1 55 5.4996 4...  (101)->(103) - [23]
# 4    CONF 39 1104 6.20513 23.3554 242 1 55 5.4996 4...  (101)->(113) - [22]
# ..                                                 ...                  ...
# 416  CONF 39 1104 6.20513 23.3554 242 1 55 5.4996 4...  (324)->(225) - [25]
# 417  CONF 39 1104 6.20513 23.3554 242 1 55 5.4996 4...  (324)->(256) - [23]
# 418  CONF 39 1104 6.20513 23.3554 242 1 55 5.4996 4...  (324)->(270) - [22]
# 419  CONF 39 1104 6.20513 23.3554 242 1 55 5.4996 4...         (326) - [20]
# 420  CONF 39 1104 6.20513 23.3554 242 1 55 5.4996 4...         (359) - [23]
#
# [421 rows x 5 columns]

# %%
rln4
# Out:
#     nsequences                                            seqstrm  \
# 0           23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 1           23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 2           23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 3           23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 4           23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 5           23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 6           23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 7           23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 8           23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 9           23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 10          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 11          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 12          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 13          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 14          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 15          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 16          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 17          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 18          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 19          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 20          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 21          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 22          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 23          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 24          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 25          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 26          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 27          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 28          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 29          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
# 30          23  549 -- 15 15 \n551 -- 15 15 \n553 -- 20 20 \n5...
#
#                                                logger  \
# 0   CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 1   CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 2   CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 3   CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 4   CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 5   CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 6   CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 7   CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 8   CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 9   CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 10  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 11  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 12  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 13  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 14  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 15  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 16  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 17  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 18  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 19  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 20  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 21  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 22  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 23  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 24  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 25  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 26  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 27  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 28  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 29  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
# 30  CONF 23 1105 9.25243 4.47826\nargs.MINSUPPORT ...
#
#                                               summary        mined_objects
# 0   CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (549) - [15]
# 1   CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (551) - [15]
# 2   CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (553) - [20]
# 3   CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...  (553)->(585) - [14]
# 4   CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...  (553)->(641) - [13]
# 5   CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (554) - [21]
# 6   CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...  (554)->(585) - [12]
# 7   CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...  (554)->(641) - [12]
# 8   CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (556) - [23]
# 9   CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...  (556)->(585) - [12]
# 10  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...  (556)->(641) - [14]
# 11  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (557) - [16]
# 12  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (558) - [19]
# 13  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (563) - [19]
# 14  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (565) - [21]
# 15  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (567) - [15]
# 16  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (577) - [20]
# 17  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...  (577)->(641) - [13]
# 18  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (583) - [17]
# 19  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...  (583)->(585) - [12]
# 20  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...  (583)->(641) - [12]
# 21  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (585) - [18]
# 22  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (588) - [21]
# 23  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...  (588)->(585) - [12]
# 24  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...  (588)->(641) - [12]
# 25  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (589) - [14]
# 26  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (596) - [15]
# 27  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...  (596)->(641) - [12]
# 28  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (626) - [15]
# 29  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (641) - [19]
# 30  CONF 23 1105 4.47826 9.25243 103 1 158 3.83322...         (844) - [14]

# %%
rln5
# Out:
#     nsequences                                            seqstrm  \
# 0           38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 1           38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 2           38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 3           38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 4           38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 5           38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 6           38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 7           38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 8           38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 9           38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 10          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 11          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 12          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 13          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 14          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 15          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 16          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 17          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 18          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 19          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 20          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 21          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 22          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 23          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 24          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 25          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 26          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
# 27          38  548 -- 21 21 \n549 -- 31 31 \n550 -- 20 20 \n5...
#
#                                                logger  \
# 0   CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 1   CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 2   CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 3   CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 4   CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 5   CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 6   CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 7   CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 8   CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 9   CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 10  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 11  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 12  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 13  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 14  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 15  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 16  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 17  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 18  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 19  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 20  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 21  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 22  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 23  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 24  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 25  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 26  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
# 27  CONF 38 1151 9.44 4.60526\nargs.MINSUPPORT 20 ...
#
#                                               summary         mined_objects
# 0   CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...         (1050) - [30]
# 1   CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (548) - [21]
# 2   CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (549) - [31]
# 3   CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...  (549)->(1050) - [19]
# 4   CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (550) - [20]
# 5   CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (551) - [29]
# 6   CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (552) - [20]
# 7   CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (553) - [36]
# 8   CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (554) - [34]
# 9   CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (555) - [23]
# 10  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (556) - [35]
# 11  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...  (556)->(1050) - [19]
# 12  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (557) - [22]
# 13  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (563) - [25]
# 14  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (581) - [21]
# 15  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (583) - [32]
# 16  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...  (583)->(1050) - [21]
# 17  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (585) - [30]
# 18  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...  (585)->(1050) - [20]
# 19  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (588) - [37]
# 20  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...  (588)->(1050) - [23]
# 21  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (589) - [31]
# 22  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (598) - [27]
# 23  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (620) - [22]
# 24  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (626) - [24]
# 25  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (641) - [37]
# 26  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (790) - [32]
# 27  CONF 38 1151 4.60526 9.44 175 1 130 4.87742 25...          (844) - [23]
